# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
#import psycopg2 
import os

# %%
# %pwd #find where we are
# Out:
# '/Users/lisaschreiber/Desktop/University Learning Dataset'

# %%
dfstudentinfo = pd.read_csv("studentInfo.csv")
dfstudentassess = pd.read_csv("studentAssessment.csv")
#dfvle = pd.read_csv("vle.csv")
#dfstudentvle = pd.read_csv("studentVle.csv")
#dfstudentreg = pd.read_csv ("studentRegistration.csv")
#dfcourses = pd.read_csv ("courses.csv")
#dfasses = pd.read_csv ("coruses.csv")

# %%
#Viewing the 10 rows of the Student Info Table/Dataframe
dfstudentinfo.head(10)
dfstudentinfo.shape
# Out:
# (32593, 12)

# %%
#Viewing the total number of students and features/columns of the dataframe. 
id_student, num_features = dfstudentinfo.shape

print(id_student)
print(num_features)
# Out:
# 32593
# 12

# %%
#Check Data Type

dfstudentinfo.dtypes
# Out:
# code_module             object
# code_presentation       object
# id_student               int64
# gender                  object
# region                  object
# highest_education       object
# imd_band                object
# age_band                object
# num_of_prev_attempts     int64
# studied_credits          int64
# disability              object
# final_result            object
# dtype: object

# %%
#dfstudentinfo.info

# %%
dfstudentassess.head(10)
# Out:
#    id_assessment  id_student  date_submitted  is_banked  score
# 0           1752       11391              18          0   78.0
# 1           1752       28400              22          0   70.0
# 2           1752       31604              17          0   72.0
# 3           1752       32885              26          0   69.0
# 4           1752       38053              19          0   79.0
# 5           1752       45462              20          0   70.0
# 6           1752       45642              18          0   72.0
# 7           1752       52130              19          0   72.0
# 8           1752       53025               9          0   71.0
# 9           1752       57506              18          0   68.0

# %%
dfstudentassess.shape
# Out:
# (173912, 5)

# %%
print(f"{dfstudentassess['id_assessment'].unique()}")
# Out:
# [ 1752  1753  1754  1755  1756  1758  1759  1760  1761  1762 14984 14985
#  14986 14987 14988 14989 14991 14992 14993 14994 14995 14996 14997 14998
#  14999 15000 15001 15003 15004 15005 15006 15007 15008 15009 15010 15011
#  15012 15013 15015 15016 15017 15018 15019 15020 15021 15022 15023 15024
#  24282 24283 24284 24285 24286 24287 24288 24289 24290 24291 24292 24293
#  24294 24295 24296 24297 24298 24299 25334 25335 25336 25337 25338 25339
#  25340 25341 25342 25343 25344 25345 25346 25347 25348 25349 25350 25351
#  25352 25353 25354 25355 25356 25357 25358 25359 25360 25361 25362 25363
#  25364 25365 25366 25367 25368 30709 30710 30711 30712 30714 30715 30716
#  30717 30719 30720 30721 30722 34860 34861 34862 34863 34864 34865 34866
#  34867 34868 34869 34870 34871 34873 34874 34875 34876 34877 34878 34879
#  34880 34881 34882 34883 34884 34886 34887 34888 34889 34890 34891 34892
#  34893 34894 34895 34896 34897 34899 34900 34901 34902 34903 34904 34905
# ...

# %%
#dfstudentassess.groupby(['id_assessment','score']).sum()

# %%
print(f"{dfstudentassess['id_assessment'].nunique()}")
# Out:
# 188

# %%
dfstudentassess.describe(include='all')
# Out:
#        id_assessment    id_student  date_submitted      is_banked  \
# count  173912.000000  1.739120e+05   173912.000000  173912.000000
# mean    26553.803556  7.051507e+05      116.032942       0.010977
# std      8829.784254  5.523952e+05       71.484148       0.104194
# min      1752.000000  6.516000e+03      -11.000000       0.000000
# 25%     15022.000000  5.044290e+05       51.000000       0.000000
# 50%     25359.000000  5.852080e+05      116.000000       0.000000
# 75%     34883.000000  6.344980e+05      173.000000       0.000000
# max     37443.000000  2.698588e+06      608.000000       1.000000
#
#                score
# count  173739.000000
# mean       75.799573
# std        18.798107
# min         0.000000
# 25%        65.000000
# 50%        80.000000
# 75%        90.000000
# max       100.000000

# %%
df= dfstudentassess.drop(['is_banked',], axis=1)
df.head(20)
# Out:
#     id_assessment  id_student  date_submitted  score
# 0            1752       11391              18   78.0
# 1            1752       28400              22   70.0
# 2            1752       31604              17   72.0
# 3            1752       32885              26   69.0
# 4            1752       38053              19   79.0
# 5            1752       45462              20   70.0
# 6            1752       45642              18   72.0
# 7            1752       52130              19   72.0
# 8            1752       53025               9   71.0
# 9            1752       57506              18   68.0
# 10           1752       58873              19   73.0
# 11           1752       59185              18   67.0
# 12           1752       62155              17   73.0
# 13           1752       63400              19   83.0
# 14           1752       65002              17   66.0
# 15           1752       70464              19   59.0
# 16           1752       71361              19   82.0
# ...

# %%
dfcourses = pd.read_csv ("courses.csv")

# %%
dfcourses.describe()
# Out:
#        module_presentation_length
# count                   22.000000
# mean                   255.545455
# std                     13.654677
# min                    234.000000
# 25%                    241.000000
# 50%                    261.500000
# 75%                    268.000000
# max                    269.000000

# %%
dfcourses.shape
# Out:
# (22, 3)

# %%
dfcourses.head(10)
# Out:
#   code_module code_presentation  module_presentation_length
# 0         AAA             2013J                         268
# 1         AAA             2014J                         269
# 2         BBB             2013J                         268
# 3         BBB             2014J                         262
# 4         BBB             2013B                         240
# 5         BBB             2014B                         234
# 6         CCC             2014J                         269
# 7         CCC             2014B                         241
# 8         DDD             2013J                         261
# 9         DDD             2014J                         262

# %%
#Attempting To Merge Tables

# %%
merged_df = pd.merge(df, dfstudentassess, on='id_student', how='left')

# %%
merged_df.shape
# Out:
# (1711176, 8)

# %%
#Dataframe not yet Normalized. As one can observe there are multiple entries per Student (id_student) depending on assessment type taken (id_assessment) for exampel
merged_df.head(15)
# Out:
#     id_assessment_x  id_student  date_submitted_x  score_x  id_assessment_y  \
# 0              1752       11391                18     78.0             1752
# 1              1752       11391                18     78.0             1753
# 2              1752       11391                18     78.0             1754
# 3              1752       11391                18     78.0             1755
# 4              1752       11391                18     78.0             1756
# 5              1752       28400                22     70.0             1752
# 6              1752       28400                22     70.0             1753
# 7              1752       28400                22     70.0             1754
# 8              1752       28400                22     70.0             1755
# 9              1752       28400                22     70.0             1756
# 10             1752       31604                17     72.0             1752
# ...

# %%
#Descriptive Statistics

# %%
dfstudentinfo['disability'].value_counts().plot(kind='bar')

# %%
dfstudentinfo['gender'].value_counts().plot(kind='bar')

# %%
dfstudentinfo.groupby(['final_result','gender']).size().unstack().plot(kind='bar',stacked=True)
plt.show()

# %%
dfstudentinfo.groupby(['gender', 'final_result']).size().unstack().plot(kind='bar',stacked=True)
plt.show()

# %%
a = dfstudentinfo['id_student'].values.tolist()

# %%
# Obtaining the Total Number of Students? Skewed value as total contains duplicates. 
dfstudentinfo['id_student'].count()
# Out:
# 32593

# %%
import collections
duplicates = [item for item, count in collections.Counter(a).items() if count > 1]

# %%
len(duplicates)
# Out:
# 3538

# %%
dfstudentinfo.id_student.duplicated().sum()
# Out:
# 3808

# %%
#Finding the rows with duplicate id_student entries.
dfstudentinfo.loc[df.id_student.duplicated(keep = False), :]
# Out:
#       code_module code_presentation  id_student gender                region  \
# 0             AAA             2013J       11391      M   East Anglian Region
# 1             AAA             2013J       28400      F              Scotland
# 2             AAA             2013J       30268      F  North Western Region
# 3             AAA             2013J       31604      F     South East Region
# 4             AAA             2013J       32885      F  West Midlands Region
# 5             AAA             2013J       38053      M                 Wales
# 6             AAA             2013J       45462      M              Scotland
# 7             AAA             2013J       45642      F  North Western Region
# 8             AAA             2013J       52130      F   East Anglian Region
# 9             AAA             2013J       53025      M          North Region
# 10            AAA             2013J       57506      M          South Region
# ...

# %%
#df['region'].nunique()

# %%
dfstudentinfo.groupby(['final_result','gender','region'])['final_result'].count()
# Out:
# final_result  gender  region
# Distinction   F       East Anglian Region     154
#                       East Midlands Region    102
#                       Ireland                  33
#                       London Region           110
#                       North Region             75
#                       North Western Region     91
#                       Scotland                138
#                       South East Region       143
#                       South Region            153
#                       South West Region       139
#                       Wales                    88
#                       West Midlands Region     76
#                       Yorkshire Region         92
#               M       East Anglian Region     173
#                       East Midlands Region     98
#                       Ireland                  65
#                       London Region           153
#                       North Region            155
# ...

# %%
#df['id_student'].unique().tolist()

# %%
dfstudentinfo.id_student.count() #number of rows for student id
# Out:
# 32593

# %%
dfstudentinfo["id_student"].nunique() #number of unique values
# Out:
# 28785

# %%
#Test still contains duplicates, we need to remove them before running these charts

location_counts = dfstudentinfo['region'].value_counts()
print (location_counts)


# region pie chart and histogram pie chart.  Using both visuals to see which is better at displaying the data.

plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
location_counts.plot(kind='pie')
plt.title('Location Distribution')

plt.subplot(1,2,2)
location_counts.plot(kind='bar')
plt.xlabel('Location')
plt.ylabel('Frequency')
plt.title('Location Distribution')

# add more space between the two plots
plt.subplots_adjust(wspace=0.5)
# Out:
# Scotland                3446
# East Anglian Region     3340
# London Region           3216
# South Region            3092
# North Western Region    2906
# West Midlands Region    2582
# South West Region       2436
# East Midlands Region    2365
# South East Region       2111
# Wales                   2086
# Yorkshire Region        2006
# North Region            1823
# Ireland                 1184
# Name: region, dtype: int64

# %%
dfstudentinfo['region'].count()
# Out:
# 32593

# %%
#test still contains duplicates, we need to remove them before running these charts

finalresult_counts = dfstudentinfo['final_result'].value_counts()
print (finalresult_counts)


# final result pie chart and histogram pie chart.  Using both visuals to see which is better at displaying the data.

plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
finalresult_counts.plot(kind='pie')
plt.title('Final Result Distribution')

plt.subplot(1,2,2)
finalresult_counts.plot(kind='bar')
plt.xlabel('Result')
plt.ylabel('Frequency')
plt.title('Final Result Distribution')

# add more space between the two plots
plt.subplots_adjust(wspace=0.5)
# Out:
# Pass           12361
# Withdrawn      10156
# Fail            7052
# Distinction     3024
# Name: final_result, dtype: int64

# %%
#test still contains duplicates, we need to remove them before running these charts

age_counts = dfstudentinfo['age_band'].value_counts()
print (age_counts)


# attempt pie chart and histogram pie chart.  Using both visuals to see which is better at displaying the data.

plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
age_counts.plot(kind='pie')
plt.title('Age Distribution')

plt.subplot(1,2,2)
age_counts.plot(kind='bar')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution')

# add more space between the two plots
plt.subplots_adjust(wspace=0.5)
# Out:
# 0-35     22944
# 35-55     9433
# 55<=       216
# Name: age_band, dtype: int64

# %%
#test still contains duplicates, we need to remove them before running these charts

attempt_counts = dfstudentinfo["num_of_prev_attempts"].value_counts()
print (attempt_counts)


# attempts pie chart and histogram pie chart.  Using both visuals to see which is better at displaying the data.

plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
attempt_counts.plot(kind='pie')
plt.title('Attempt Distribution')

plt.subplot(1,2,2)
attempt_counts.plot(kind='bar')
plt.xlabel('Attempts')
plt.ylabel('Frequency')
plt.title('Attempt Distribution')

# add more space between the two plots
plt.subplots_adjust(wspace=0.5)
# Out:
# 0    28421
# 1     3299
# 2      675
# 3      142
# 4       39
# 5       13
# 6        4
# Name: num_of_prev_attempts, dtype: int64

# %%
#test still contains duplicates, we need to remove them before running these charts

credit_counts = dfstudentinfo["studied_credits"].value_counts()
print (credit_counts)


# attempts pie chart and histogram pie chart.  Using both visuals to see which is better at displaying the data.

plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
credit_counts.plot(kind='pie')
plt.title('Credits Taken Distribution')

plt.subplot(1,2,2)
credit_counts.plot(kind='bar')
plt.xlabel('Credits Taken')
plt.ylabel('Frequency')
plt.title('Credits Taken Distribution')

# add more space between the two plots
plt.subplots_adjust(wspace=0.5)
# Out:
# 60     16751
# 120     6328
# 30      3749
# 90      3144
# 180      830
# 150      769
# 240      220
# 210      169
# 75       108
# 70        96
# 270       45
# 130       38
# 45        36
# 135       35
# 100       30
# 300       29
# 80        26
# 40        22
# 160       14
# 105       13
# 330       12
# 110       11
# 195       11
# 165        9
# 220        9
# 50         7
# 145        7
# 170        6
# 190        6
# 360        6
#        ...
# 140        5
# 85         4
# 200        3
# 95         3
# 55         3
# 225        3
# 250        3
# 280        3
# 205        2
# 310        2
# 400        2
# 430        1
# 480        1
# 370        1
# 175        1
# 65         1
# 235        1
# 355        1
# 420        1
# 325        1
# 155        1
# 540        1
# 390        1
# 630        1
# 215        1
# 255        1
# 345        1
# 585        1
# 315        1
# 655        1
# Name: studied_credits, Length: 61, dtype: int64

# %%
#test still contains duplicates, we need to remove them before running these charts

#we're going to need to create bins for these scores

grade_counts = dfstudentassess["score"].value_counts()



# attempts pie chart and histogram pie chart.  Using both visuals to see which is better at displaying the data.

fig = plt.figure(figsize=(7,10))
ax = fig.add_subplot(211)
ax.hist(dfstudentassess['score'], bins=20, range=(dfstudentassess['score'].min(),dfstudentassess['score'].max()))
plt.title('Score Distribution with 20 Bins')
plt.xlabel('Score')
plt.ylabel('Count of Score')
plt.show()
# Out:
# //anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# //anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
disability_counts = dfstudentinfo["disability"].value_counts()
print (disability_counts)

from matplotlib.ticker import PercentFormatter

#disibility pie chart and histogram pie chart.  Using both visuals to see which is better at displaying the data.

plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
disability_counts.plot(kind='pie')
plt.title('Disability Distribution')

plt.subplot(1,2,2)
disability_counts.plot(kind='bar')
plt.xlabel('Disability')
plt.ylabel('Frequency')
plt.title('Disability Distribution')


# add more space between the two plots
plt.subplots_adjust(wspace=0.5)
# Out:
# N    29429
# Y     3164
# Name: disability, dtype: int64

# %%
#test still contains duplicates, we need to remove them before running these charts

gender_counts = dfstudentinfo["gender"].value_counts()
print (gender_counts)


# attempts pie chart and histogram pie chart.  Using both visuals to see which is better at displaying the data.

plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
gender_counts.plot(kind='pie')
plt.title('Gender Distribution')

plt.subplot(1,2,2)
gender_counts.plot(kind='bar')
plt.xlabel('Gender')
plt.ylabel('Frequency')
plt.title('Attempt Distribution')

# add more space between the two plots
plt.subplots_adjust(wspace=0.5)

dfstudentinfo.groupby(['gender', 'final_result']).size().unstack().plot(kind='bar',stacked=True)
plt.show()
# Out:
# M    17875
# F    14718
# Name: gender, dtype: int64

# %%
import seaborn as sns

sns.set_palette("colorblind")

g = sns.pairplot(dfstudentinfo, hue="final_result")
plt.show()

# %%
g = sns.pairplot(dfstudentinfo, hue="age_band")
plt.show()

# %%
dfstudentassess.dropna().boxplot("score")

# %%
ax = dfstudentinfo.boxplot("studied_credits","region", figsize=(20,5))

# %%
ax = dfstudentinfo.boxplot("studied_credits","gender")
